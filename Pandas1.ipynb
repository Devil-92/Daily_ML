# %% [markdown]
# <a href="https://colab.research.google.com/github/Devil-92/100_Days_of_ML/blob/main/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# While pandas adopts many coding idioms from NumPy, the biggest about difference is that pandas is designed for working with tabular or heterogeneous data. NumPy, by contrast, is best suited for working with homogeneously typed numerical array data.

# %% [markdown]
# Pandas is often used in tandem with
# numerical computing tools like NumPy and SciPy, analytical libraries like statsmodels and scikit-learn, and data visualization libraries like matplotlib.

# %%
import numpy as np
import pandas as pd
from pandas import Series , DataFrame

# %% [markdown]
# ### Series

# %%
obj = pd.Series([1,2,3,4])

# %%
obj         # Values associated with Index or Data Label ( Here 0 to N-1 )
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [np.int64(1), np.int64(2), np.int64(3), np.int64(4)]
# Length: 4, dtype: int64

# %%
obj2 = pd.Series([2,4,5,7] , index = ['a' , 'b' , 'd' , 'c'])

# %%
obj2
# Out:
# a    2
# b    4
# d    5
# c    7
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'b', 'd', 'c'], dtype='object')

# %%
obj2["a"]
# Out:
# np.int64(2)

# %%
obj2["d"] = 12

# %%
obj2[["a" , "d" , "c"]]
# Out:
# a     2
# d    12
# c     7
# dtype: int64

# %%
print("The List is interpretted as indices but they are characters anyway")
# Out:
# The List is interpretted as indices but they are characters anyway

# %%
obj2[obj2>10]
# Out:
# d    12
# dtype: int64

# %%
obj2*2
# Out:
# a     4
# b     8
# d    24
# c    14
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a         7.389056
# b        54.598150
# d    162754.791419
# c      1096.633158
# dtype: float64

# %%
print("All Functions or NumPy like Operations are available on Pandas")
# Out:
# All Functions or NumPy like Operations are available on Pandas

# %%
"b" in obj2
# Out:
# True

# %%
"e" in obj2
# Out:
# False

# %%
d = {i:i**2 for i in range(1,6)}
d
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
obj3 = pd.Series(d)

# %%
obj3
# Out:
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# dtype: int64

# %%
obj3.to_dict()
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
obj3
# Out:
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# dtype: int64

# %%
idx = ['c' , 1 , 'e' , 2 , 'b']
obj4 = pd.Series(d , index = idx)
obj4
# Out:
# c    NaN
# 1    1.0
# e    NaN
# 2    4.0
# b    NaN
# dtype: float64

# %%
print("Here pd is able to find the 1 and 2 keys but proceed to output Nan Values for the unknown keys")
# Out:
# Here pd is able to find the 1 and 2 keys but proceed to output Nan Values for the unknown keys

# %%
obj4.isna()
# Out:
# c     True
# 1    False
# e     True
# 2    False
# b     True
# dtype: bool

# %%
obj4.notna()
# Out:
# c    False
# 1     True
# e    False
# 2     True
# b    False
# dtype: bool

# %%
obj3
# Out:
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# dtype: int64

# %%
obj4
# Out:
# c    NaN
# 1    1.0
# e    NaN
# 2    4.0
# b    NaN
# dtype: float64

# %%
obj3 + obj4
# Out:
# 1    2.0
# 2    8.0
# 3    NaN
# 4    NaN
# 5    NaN
# b    NaN
# c    NaN
# e    NaN
# dtype: float64

# %%
print("Any operation with NaN value results in NaN , Hence here for index 3 : 2 + NaN = NaN")
# Out:
# Any operation with NaN value results in NaN , Hence here for index 3 : 2 + NaN = NaN

# %%
print("Pandas + operator automatically aligns by index as sql join")
# Out:
# Pandas + operator automatically aligns by index as sql join

# %%
obj4.index.name = "num"
obj4.name = "Table"

# %%
obj4
# Out:
# num
# c    NaN
# 1    1.0
# e    NaN
# 2    4.0
# b    NaN
# Name: Table, dtype: float64

# %%
idx = [1,2,3,4,5]
obj4.index = idx
obj4
# Out:
# 1    NaN
# 2    1.0
# 3    NaN
# 4    4.0
# 5    NaN
# Name: Table, dtype: float64

# %%
print("Series index can be modified on place")
# Out:
# Series index can be modified on place

# %% [markdown]
# ### DataFrame

# %%
print("DataFrame can be considered a collection of Series")
# Out:
# DataFrame can be considered a collection of Series

# %%
print("It can hold heterogenous data")
# Out:
# It can hold heterogenous data

# %%
data = {
    "State" : ["West Bengal" , "Bihar" , "Jharkhand" , "Assam" , "Orissa"] ,
    "Population " : [100 , 101 , 102 , 103 , 104],
    "Year" : [2020 , 2021 , 2022 , 2023 , 2024]
    }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          State  Population   Year
# 0  West Bengal          100  2020
# 1        Bihar          101  2021
# 2    Jharkhand          102  2022
# 3        Assam          103  2023
# 4       Orissa          104  2024

# %%
print("One way of Creating dataframe is dict with equal length lists")
# Out:
# One way of Creating dataframe is dict with equal length lists

# %%
df.head()
# Out:
#          State  Population   Year
# 0  West Bengal          100  2020
# 1        Bihar          101  2021
# 2    Jharkhand          102  2022
# 3        Assam          103  2023
# 4       Orissa          104  2024

# %%
df.tail()
# Out:
#          State  Population   Year
# 0  West Bengal          100  2020
# 1        Bihar          101  2021
# 2    Jharkhand          102  2022
# 3        Assam          103  2023
# 4       Orissa          104  2024

# %%
pd.DataFrame(data , columns = ["Year" , "State" , "Population"])        # Columns can be arranged
# Out:
#    Year        State Population
# 0  2020  West Bengal        NaN
# 1  2021        Bihar        NaN
# 2  2022    Jharkhand        NaN
# 3  2023        Assam        NaN
# 4  2024       Orissa        NaN

# %%
df2 = pd.DataFrame(data , columns = ["Year" , "State" , "Population" , "Nothing"])
df2
# Out:
#    Year        State Population Nothing
# 0  2020  West Bengal        NaN     NaN
# 1  2021        Bihar        NaN     NaN
# 2  2022    Jharkhand        NaN     NaN
# 3  2023        Assam        NaN     NaN
# 4  2024       Orissa        NaN     NaN

# %%
print("Additional columns will appear with NaN values")
# Out:
# Additional columns will appear with NaN values

# %%
df2.columns
# Out:
# Index(['Year', 'State', 'Population', 'Nothing'], dtype='object')

# %%
df2["State"].value_counts()
# Out:
# State
# West Bengal    1
# Bihar          1
# Jharkhand      1
# Assam          1
# Orissa         1
# Name: count, dtype: int64

# %%
df2["State"]
# Out:
# 0    West Bengal
# 1          Bihar
# 2      Jharkhand
# 3          Assam
# 4         Orissa
# Name: State, dtype: object

# %%
df2.State
# Out:
# 0    West Bengal
# 1          Bihar
# 2      Jharkhand
# 3          Assam
# 4         Orissa
# Name: State, dtype: object

# %%
print("""frame2[column] works for any column name, but frame2.column works only when the column name is a valid Python variable name
and does not conflict with any of the method names in DataFrame""")
# Out:
# frame2[column] works for any column name, but frame2.column works only when the column name is a valid Python variable name
# and does not conflict with any of the method names in DataFrame

# %%
df2.loc[1]              # Name Attribute
# Out:
# Year           2021
# State         Bihar
# Population      NaN
# Nothing         NaN
# Name: 1, dtype: object

# %%
df2.iloc[2]             # Position Attribute
# Out:
# Year               2022
# State         Jharkhand
# Population          NaN
# Nothing             NaN
# Name: 2, dtype: object

# %%
df2["Nothing"] = 12
df2
# Out:
#    Year        State Population  Nothing
# 0  2020  West Bengal        NaN       12
# 1  2021        Bihar        NaN       12
# 2  2022    Jharkhand        NaN       12
# 3  2023        Assam        NaN       12
# 4  2024       Orissa        NaN       12

# %%
df2["Nothing"] = np.arange(1 , 6)

# %%
df2
# Out:
#    Year        State Population  Nothing
# 0  2020  West Bengal        NaN        1
# 1  2021        Bihar        NaN        2
# 2  2022    Jharkhand        NaN        3
# 3  2023        Assam        NaN        4
# 4  2024       Orissa        NaN        5

# %%
val = pd.Series([-1 , -2 , -3] , index = [1 , 2 , 3])
df2["Nothing"] = val

# %%
df2
# Out:
#    Year        State Population  Nothing
# 0  2020  West Bengal        NaN      NaN
# 1  2021        Bihar        NaN     -1.0
# 2  2022    Jharkhand        NaN     -2.0
# 3  2023        Assam        NaN     -3.0
# 4  2024       Orissa        NaN      NaN

# %%
print("Usually assigning a list or arrays to a column and if it's length doesn't match with column length , it raises a Error ")
# Out:
# Usually assigning a list or arrays to a column and if it's length doesn't match with column length , it raises a Error

# %%
print("But a pd.Series assigns the indices available and assigns NaN values to the indices not present")
# Out:
# But a pd.Series assigns the indices available and assigns NaN values to the indices not present

# %%
df2["Bengal"] = df2["State"] == "West Bengal"
df2
# Out:
#    Year        State Population  Nothing  Bengal
# 0  2020  West Bengal        NaN      NaN    True
# 1  2021        Bihar        NaN     -1.0   False
# 2  2022    Jharkhand        NaN     -2.0   False
# 3  2023        Assam        NaN     -3.0   False
# 4  2024       Orissa        NaN      NaN   False

# %%
print("New columns cannot be created with . attribute")
# Out:
# New columns cannot be created with . attribute

# %%
del df2["Bengal"]

# %%
df2
# Out:
#    Year        State Population  Nothing
# 0  2020  West Bengal        NaN      NaN
# 1  2021        Bihar        NaN     -1.0
# 2  2022    Jharkhand        NaN     -2.0
# 3  2023        Assam        NaN     -3.0
# 4  2024       Orissa        NaN      NaN

# %%
popu = {
    "Ohio" : {2000 : 1.5 , 2001 : 1.7 , 2002 : 3.6},
    "Nevada" : {2001 : 2.4 , 2002 : 2.9}
}

# %%
print("Another Way of Initializing DataFrame")
# Out:
# Another Way of Initializing DataFrame

# %%
print("For nested Dict outer keys serves as Columns and inner keys serve as Rows ")
# Out:
# For nested Dict outer keys serves as Columns and inner keys serve as Rows

# %%
df3 = pd.DataFrame(popu)
df3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
df3.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9

# %%
print("Taking Transpose losses datatypes as all values are converted to python objects")
# Out:
# Taking Transpose losses datatypes as all values are converted to python objects

# %%
pd.DataFrame(popu , index = [2001 , 2002 , 2003])
# Out:
#       Ohio  Nevada
# 2001   1.7     2.4
# 2002   3.6     2.9
# 2003   NaN     NaN

# %%
print("We can do explicit indexing by assigning idx column")
# Out:
# We can do explicit indexing by assigning idx column

# %% [markdown]
# Possible Data Inputs to a DataFrame
# ![Screenshot 2026-08-14 at 09.44.16.png](data:image/png;base64,...)

# %%
df3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
df3.index.name = "Year"
df3.columns.name = "State"
df3
# Out:
# State  Ohio  Nevada
# Year
# 2000    1.5     NaN
# 2001    1.7     2.4
# 2002    3.6     2.9

# %%
df3.to_numpy()
# Out:
# array([[1.5, nan],
#        [1.7, 2.4],
#        [3.6, 2.9]])

# %%
df2.to_numpy()
# Out:
# array([[2020, 'West Bengal', nan, nan],
#        [2021, 'Bihar', nan, -1.0],
#        [2022, 'Jharkhand', nan, -2.0],
#        [2023, 'Assam', nan, -3.0],
#        [2024, 'Orissa', nan, nan]], dtype=object)

# %% [markdown]
# ### Index Objects

# %%
print("Index Objects are responsible for holding the axis labels and its metadata")
# Out:
# Index Objects are responsible for holding the axis labels and its metadata

# %%
print("Any array or sequence passed to Construct a Series or Dataframe is internally Converted to Index")
# Out:
# Any array or sequence passed to Construct a Series or Dataframe is internally Converted to Index

# %%
obj = pd.Series(range(3) , index = ['a' , 'b' , 'c'])
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
obj.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
print(obj.array)
# Out:
# <NumpyExtensionArray>
# [np.int64(0), np.int64(1), np.int64(2)]
# Length: 3, dtype: int64

# %%
idx = obj.index

# %%
idx
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
idx[:1]
# Out:
# Index(['a'], dtype='object')

# %%
# idx[1] = "d"
print("Pandas Index Objects are immutable and this line gives Type Error")
# Out:
# Pandas Index Objects are immutable and this line gives Type Error

# %%
labels = pd.Index(np.arange(3))
labels
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
obj2 = pd.Series([1.5 , -2.5 , 9] , index = labels)
obj2
# Out:
# 0    1.5
# 1   -2.5
# 2    9.0
# dtype: float64

# %%
obj2.index is labels
# Out:
# True

# %%
df3
# Out:
# State  Ohio  Nevada
# Year
# 2000    1.5     NaN
# 2001    1.7     2.4
# 2002    3.6     2.9

# %%
df3.columns
# Out:
# Index(['Ohio', 'Nevada'], dtype='object', name='State')

# %%
"Ohio" in df3.columns
# Out:
# True

# %%
print("Index also behaves like fized size set")
# Out:
# Index also behaves like fized size set

# %%
print("But unline Python Index Objects can have duplicate items and selecting them calls all occurences of that label")
# Out:
# But unline Python Index Objects can have duplicate items and selecting them calls all occurences of that label

# %%
df = pd.DataFrame([1,2,3,4,5] , index = [100 , 200 , 300 , 400 , 500])
df
# Out:
#      0
# 100  1
# 200  2
# 300  3
# 400  4
# 500  5

# %%
df.index
# Out:
# Index([100, 200, 300, 400, 500], dtype='int64')

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
new_idx = df.index.append(pd.Index([600]))

# %%
df_new_index = df.reindex(new_idx)

# %%
df_new_index
# Out:
#        0
# 100  1.0
# 200  2.0
# 300  3.0
# 400  4.0
# 500  5.0
# 600  NaN

# %%
df.index.difference([100 , 200])
# Out:
# Index([300, 400, 500], dtype='int64')

# %%
df.index.union([600])
# Out:
# Index([100, 200, 300, 400, 500, 600], dtype='int64')

# %%
df.index.isin([200 , 400])
# Out:
# array([False,  True, False,  True, False])

# %%
df.index.delete(0)
# Out:
# Index([200, 300, 400, 500], dtype='int64')

# %%
df.index.drop([300])
# Out:
# Index([100, 200, 400, 500], dtype='int64')

# %%
df.index.insert(0 , 50)
# Out:
# Index([50, 100, 200, 300, 400, 500], dtype='int64')

# %%
df.index.is_monotonic_increasing
# Out:
# True

# %%
df.index.is_unique
# Out:
# True

# %%
df.index.unique()
# Out:
# Index([100, 200, 300, 400, 500], dtype='int64')

# %%
df
# Out:
#      0
# 100  1
# 200  2
# 300  3
# 400  4
# 500  5

# %%
print("As index is immutable , For changing df we have to modify it")
# Out:
# As index is immutable , For changing df we have to modify it

# %% [markdown]
# ### Reindexing

# %%
df = pd.Series([1 , 2 , 3 , 4 ] , index = ['a' , 'b' , 'c' , 'd'])
df
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
idx = ['a' , 'b' , 'c' , 'd' , 'e']
df2 = df.reindex(idx)
df2
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    NaN
# dtype: float64

# %%
print("For ordered time series data we want to do interpolation or forward filling for missing values")
# Out:
# For ordered time series data we want to do interpolation or forward filling for missing values

# %%
df = pd.Series(['Blue' , 'Purple' , 'Green'] , index = [0 , 1 , 2])
df
# Out:
# 0      Blue
# 1    Purple
# 2     Green
# dtype: object

# %%
df.reindex(np.arange(6) , method = "ffill")
# Out:
# 0      Blue
# 1    Purple
# 2     Green
# 3     Green
# 4     Green
# 5     Green
# dtype: object

# %%
print("We can pass the reindex to both columns and labels of the DataFrame")
# Out:
# We can pass the reindex to both columns and labels of the DataFrame

# %%
df = pd.DataFrame(np.arange(9).reshape((3,3)) , index = ['a' , 'b' , 'c'] , columns = ['A' , 'B' , 'C'])
df
# Out:
#    A  B  C
# a  0  1  2
# b  3  4  5
# c  6  7  8

# %%
df2 = df.reindex(index = ['a' , 'b' , 'c' , 'd' , 'e'])
df2
# Out:
#      A    B    C
# a  0.0  1.0  2.0
# b  3.0  4.0  5.0
# c  6.0  7.0  8.0
# d  NaN  NaN  NaN
# e  NaN  NaN  NaN

# %%
df3 = df2.reindex(columns = ["A" , 'B' , 'C' , 'D'])
df3
# Out:
#      A    B    C   D
# a  0.0  1.0  2.0 NaN
# b  3.0  4.0  5.0 NaN
# c  6.0  7.0  8.0 NaN
# d  NaN  NaN  NaN NaN
# e  NaN  NaN  NaN NaN

# %%
print("Other way out is setting the axis = columns")
# Out:
# Other way out is setting the axis = columns

# %%
df3 = df2.reindex(["A" , 'B' , 'C' , 'D'] , axis = "columns")

# %%
df3
# Out:
#      A    B    C   D
# a  0.0  1.0  2.0 NaN
# b  3.0  4.0  5.0 NaN
# c  6.0  7.0  8.0 NaN
# d  NaN  NaN  NaN NaN
# e  NaN  NaN  NaN NaN

# %%
df3.loc[['a' , 'c'] , ['A' , 'C']]
# Out:
#      A    C
# a  0.0  2.0
# c  6.0  8.0

# %%
# df.reindex(index , columns , axis , method , fill_value , limit)

# %% [markdown]
# ### Dropping Entries from an Axis

# %%
df = pd.Series(np.arange(6) , index = ['a' , 'b' , 'c' , 'd' , 'e' , 'f'])
df
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# dtype: int64

# %%
print("We can use reindexing to drop columns as well")
# Out:
# We can use reindexing to drop columns as well

# %%
df.drop('e')
# Out:
# a    0
# b    1
# c    2
# d    3
# f    5
# dtype: int64

# %%
df2 = df.drop('e')

# %%
df2
# Out:
# a    0
# b    1
# c    2
# d    3
# f    5
# dtype: int64

# %%
print("Using Drop returns a copy of the DataFrame and does not modify the original one")
# Out:
# Using Drop returns a copy of the DataFrame and does not modify the original one

# %%
df.drop(['e' , 'a'])
# Out:
# b    1
# c    2
# d    3
# f    5
# dtype: int64

# %%
df = pd.DataFrame(np.arange(16).reshape((4,4)) , index = ['a' , 'b' , 'c' , 'd'] , columns = ['A' , 'B' , 'C' , 'D'])
df
# Out:
#     A   B   C   D
# a   0   1   2   3
# b   4   5   6   7
# c   8   9  10  11
# d  12  13  14  15

# %%
df.drop(index = ['a' , 'b'])
# Out:
#     A   B   C   D
# c   8   9  10  11
# d  12  13  14  15

# %%
df.drop(columns = ['A' , 'B'])
# Out:
#     C   D
# a   2   3
# b   6   7
# c  10  11
# d  14  15

# %%
df.drop(['a' , 'b'] , axis = 0)
# Out:
#     A   B   C   D
# c   8   9  10  11
# d  12  13  14  15

# %%
df.drop(['a' , 'b'] , axis = "index")
# Out:
#     A   B   C   D
# c   8   9  10  11
# d  12  13  14  15

# %%
df.drop(['A' , 'B'] , axis = 1)
# Out:
#     C   D
# a   2   3
# b   6   7
# c  10  11
# d  14  15

# %%
df.drop(['A' , 'B'] , axis = "columns")
# Out:
#     C   D
# a   2   3
# b   6   7
# c  10  11
# d  14  15

# %%
df.drop(index = ['a' , 'b'] , columns = ['A' , 'B'])
# Out:
#     C   D
# c  10  11
# d  14  15

# %% [markdown]
# ### Indexing , Selection and Filtering

# %%
df = pd.Series(np.arange(5) , index = ['a' , 'b' , 'c' ,'d' , 'e'])
df
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
df["a"]
# Out:
# np.int64(0)

# %%
df[['a' , 'b']]
# Out:
# a    0
# b    1
# dtype: int64

# %%
print(df[1])
# Out:
# 1
# /tmp/ipykernel_33123/1490398467.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df[1])

# %%
df[1:3]
# Out:
# b    1
# c    2
# dtype: int64

# %%
df[df>2]
# Out:
# d    3
# e    4
# dtype: int64

# %%
print("As Outputed above [] this switches behavior based on situation , that's why .loc is preffered")
# Out:
# As Outputed above [] this switches behavior based on situation , that's why .loc is preffered

# %%
df.loc[['a']]
# Out:
# a    0
# dtype: int64

# %%
df.loc[['a' , 'b']]
# Out:
# a    0
# b    1
# dtype: int64

# %%
df.loc[['a' , 'b' , 'd']]
# Out:
# a    0
# b    1
# d    3
# dtype: int64

# %%
df.loc['a' : 'd']             # Endpoints are insclusive
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
print(".loc is label based while .iloc is position based")
# Out:
# .loc is label based while .iloc is position based

# %%
obj1 = pd.Series([1,2,3] , index = [2 , 0 , 1])
obj2 = pd.Series([1,2,3] , index = ['a' , 'b' , 'c'])

# %%
obj1
# Out:
# 2    1
# 0    2
# 1    3
# dtype: int64

# %%
obj2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj2.iloc[[0,1,2]]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj1.iloc[[0,1,2]]            # Value for obj1.loc is different
# Out:
# 2    1
# 0    2
# 1    3
# dtype: int64

# %%
obj1.loc[[0,1,2]]
# Out:
# 0    2
# 1    3
# 2    1
# dtype: int64

# %%
print("It is evident that loc fails when the index is not an integer")
# Out:
# It is evident that loc fails when the index is not an integer

# %%
obj2.loc['b' : 'c'] = 5
obj2
# Out:
# a    1
# b    5
# c    5
# dtype: int64

# %%
data = pd.DataFrame(np.arange(16).reshape((4,4)) , index = ['a' , 'b' , 'c' , 'd'] , columns = ['A' , 'B' , 'C' , 'D'])

# %%
data
# Out:
#     A   B   C   D
# a   0   1   2   3
# b   4   5   6   7
# c   8   9  10  11
# d  12  13  14  15

# %%
data['B']
# Out:
# a     1
# b     5
# c     9
# d    13
# Name: B, dtype: int64

# %%
data[['B' , 'C']]
# Out:
#     B   C
# a   1   2
# b   5   6
# c   9  10
# d  13  14

# %%
data[:2]
# Out:
#    A  B  C  D
# a  0  1  2  3
# b  4  5  6  7

# %%
data.iloc[:2 , 1:]        # Upto 2nd row and all columns after 1
# Out:
#    B  C  D
# a  1  2  3
# b  5  6  7

# %%
data[data['B'] > 5]          # Keep those rows where 'B' > 5
# Out:
#     A   B   C   D
# c   8   9  10  11
# d  12  13  14  15

# %%
data > 5
# Out:
#        A      B      C      D
# a  False  False  False  False
# b  False  False   True   True
# c   True   True   True   True
# d   True   True   True   True

# %%
data[data > 5]
# Out:
#       A     B     C     D
# a   NaN   NaN   NaN   NaN
# b   NaN   NaN   6.0   7.0
# c   8.0   9.0  10.0  11.0
# d  12.0  13.0  14.0  15.0

# %%
data[data < 5] = 0

# %%
data
# Out:
#     A   B   C   D
# a   0   0   0   0
# b   0   5   6   7
# c   8   9  10  11
# d  12  13  14  15

# %%
data.loc['b']
# Out:
# A    0
# B    5
# C    6
# D    7
# Name: b, dtype: int64

# %%
data.loc[: , 'B']
# Out:
# a     0
# b     5
# c     9
# d    13
# Name: B, dtype: int64

# %%
data.loc[['a' , 'b' ],['A' , 'C'] ]
# Out:
#    A  C
# a  0  0
# b  0  6

# %%
data.iloc[2]
# Out:
# A     8
# B     9
# C    10
# D    11
# Name: c, dtype: int64

# %%
data.iloc[[0 , 1] , [0 , 2]]
# Out:
#    A  C
# a  0  0
# b  0  6

# %%
data.iloc[[0] , [1,2,3]]
# Out:
#    B  C  D
# a  0  0  0

# %%
data.loc[:'c' , 'A']
# Out:
# a    0
# b    0
# c    8
# Name: A, dtype: int64

# %%
data.iloc[: , :3]
# Out:
#     A   B   C
# a   0   0   0
# b   0   5   6
# c   8   9  10
# d  12  13  14

# %%
data.iloc[: , :3][data['C'] > 5]
# Out:
#     A   B   C
# b   0   5   6
# c   8   9  10
# d  12  13  14

# %%
data.loc[data['C'] >= 2]
# Out:
#     A   B   C   D
# b   0   5   6   7
# c   8   9  10  11
# d  12  13  14  15

# %%
print("Boolean Arrays can be used with loc but not with iloc")
# Out:
# Boolean Arrays can be used with loc but not with iloc

# %%
data.at['a' , 'A']
# Out:
# np.int64(0)

# %%
data.iat[1 , 1]
# Out:
# np.int64(5)

# %%
print("at and iat are used to find a scalar value at that given position")
# Out:
# at and iat are used to find a scalar value at that given position

# %%
print("They are most fast and specialized than loc and iloc")
# Out:
# They are most fast and specialized than loc and iloc

# %% [markdown]
# (Indexing Options in DataFrame)
# ![Screenshot 2026-08-14 at 18.05.26.png](data:image/png;base64,...)

# %% [markdown]
# #### Integer indexing pitfalls

# %%
ser = pd.Series(np.arange(3))

# %%
ser
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
ser[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_33123/3387420178.py in <cell line: 0>()
# ----> 1 ser[-1]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
print("Will give Error as pandas fall back on integer indexing")
# Out:
# Will give Error as pandas fall back on integer indexing

# %%
ser2 = pd.Series([1,2,3] , index = ['a' , 'b' , 'c'])
ser2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser2[-1]
# Out:
# /tmp/ipykernel_33123/811950851.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser2[-1]
# np.int64(3)

# %%
print("This works fine and for these abiguity loc and iloc are mostly preffered")
# Out:
# This works fine and for these abiguity loc and iloc are mostly preffered

# %%
ser.iloc[-1]
# Out:
# np.int64(2)

# %% [markdown]
# #### Pitfalls with chained indexing

# %%
data.loc[: , 'A'] = 1

# %%
data
# Out:
#    A   B   C   D
# a  1   0   0   0
# b  1   5   6   7
# c  1   9  10  11
# d  1  13  14  15

# %%
data.iloc[2] = 5

# %%
data
# Out:
#    A   B   C   D
# a  1   0   0   0
# b  1   5   6   7
# c  5   5   5   5
# d  1  13  14  15

# %%
data.loc[data['D'] > 5] = 3
data
# Out:
#    A  B  C  D
# a  1  0  0  0
# b  3  3  3  3
# c  5  5  5  5
# d  3  3  3  3

# %%
data.loc[data['C'] == 5]['C'] = 6
# Out:
# /tmp/ipykernel_33123/912255473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data['C'] == 5]['C'] = 6

# %%
print("Doing this will not modify the dataframe as we are trying to modify a temporary value result of data.loc[data['C] == 5]")
# Out:
# Doing this will not modify the dataframe as we are trying to modify a temporary value result of data.loc[data['C] == 5]

# %%
data
# Out:
#    A  B  C  D
# a  1  0  0  0
# b  3  3  3  3
# c  5  5  5  5
# d  3  3  3  3

# %%
data.loc[data['C'] == 5 , 'C'] = 6

# %%
data
# Out:
#    A  B  C  D
# a  1  0  0  0
# b  3  3  3  3
# c  5  5  6  5
# d  3  3  3  3

# %%
print("Hence it is advised to not use chained indexing in pandas")
# Out:
# Hence it is advised to not use chained indexing in pandas
